# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv("Cleaned_file.csv")
df.head()
# Out:
#    ID                                              Tweet                Topic  \
# 0   0  #breaking - new at 8:30am: 6.6 million america...      Economy Related
# 1   1  determination is the key dictum of armed force...           Government
# 2   2  happening today! we hope you'll join us at 10:...  Hospital & Medicine
# 3   3  in times of uncertainty when theres little cla...        Mental Stress
# 4   4  @porrohman1 @childofalba @jackson_carlaw @scot...    Social Distancing
#
#                                             keywords Sentiment        Date  \
# 0  breaking new million american filed unemployme...  negative  04-09-2020
# 1  determination key dictum armed force pakistan ...  positive  04-09-2020
# 2  happening today hope join morning join convers...  positive  04-09-2020
# 3  time uncertainty little clarity event unfold f...  negative  04-09-2020
# 4  porrohman childofalba jackson carlaw scotgov c...  negative  04-09-2020
#
# ...

# %%
sns.barplot(x="Topic", y="Follower Count" ,data = df)

# %%
sns.relplot(x="Topic Rank", y="Topic", hue = "Sentiment", data = df)

# %%
counts = df["Topic"].value_counts()
plt.bar(range(len(counts)), counts)
plt.show()
print(counts)
# Out:
# Others                   7825
# Government               4643
# Social Distancing        3167
# Mental Stress            2862
# Hospital & Medicine      2448
# Economy Related           268
# Digital Platforms         259
# Small&Medium Business     174
# Software/Technology       161
# Education                 129
# Travel & Airline          116
# Unemployment               83
# Work From Home             64
# Banking Product            61
# Supply Chain               53
# Payment Related            31
# Service Delivery           21
# Name: Topic, dtype: int64

# %%
all_words = ' '.join([text for text in df['keywords']])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,background_color="white").generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.plot(x="Topic", y=["Topic Rank"])

# %%
all_words = " ".join(review for review in df[df["Sentiment"]=="positive"].keywords)

# Create and generate a word cloud image:
wordcloud = WordCloud((background_color="white",max_words=1000,width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

# Display the generated image:
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
#   File "<ipython-input-15-560e59c5a189>", line 4
#     wordcloud = WordCloud((background_color="white",max_words=1000,width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
#                                            ^
# SyntaxError: invalid syntax

# %%
all_words = " ".join(review for review in df[df["Sentiment"]=="neutral"].Tweet)

# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=100,background_color="white").generate(all_words)

# Display the generated image:
plt.figure(figsize=[10,7])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
spa=" ".join(review for review in df[df["Sentiment"]=="positive"].Tweet)

wordcloud_spa = WordCloud(background_color="white", max_words=1000,width=800, height=500, random_state=21, max_font_size=110).generate(spa)

# create coloring from image

plt.figure(figsize=[7,7])
plt.imshow(wordcloud_spa, interpolation="bilinear")
plt.axis("off")

plt.show()

# %%
all_words = " ".join(review for review in df[df["Topic"]=="Economy Related"].keywords)

# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=100,background_color="white").generate(all_words)

# Display the generated image:
plt.figure(figsize=[7,7])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
all_words = " ".join(review for review in df[df["Topic"]=="Banking Product"].keywords)

# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=100,background_color="white").generate(all_words)

# Display the generated image:
plt.figure(figsize=[7,7])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
all_words = " ".join(review for review in df[df["Topic"]=="Software/Technology"].keywords)

# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=100,background_color="white").generate(all_words)

# Display the generated image:
plt.figure(figsize=[7,7])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import sys
# !{sys.executable} -m pip install yellowbrick
# Out:
# Processing c:\users\lekha\appdata\local\pip\cache\wheels\53\ff\8a\1a6203990a3b86fb60240937bd9236f04951ad792cc27b896d\umap_learn-0.4.2-py3-none-any.whl
# ...
#   Using cached tbb-2019.0-py3-none-win_amd64.whl (194 kB)
# ...
#   Using cached scipy-1.4.1-cp37-cp37m-win_amd64.whl (30.9 MB)
# ...
#   Using cached numba-0.49.0-cp37-cp37m-win_amd64.whl (2.1 MB)
# ...
#   Using cached llvmlite-0.32.0-cp37-cp37m-win_amd64.whl (13.6 MB)
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.1.0
#     Uninstalling scipy-1.1.0:
#       Successfully uninstalled scipy-1.1.0
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\users\\lekha\\anaconda3\\lib\\site-packages\\~cipy\\cluster\\_hierarchy.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import yellowbrick

from yellowbrick.text import FreqDistVisualizer
from yellowbrick.text import TSNEVisualizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# C:\Users\Lekha\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.feature_extraction import text 

stop_words2 = text.ENGLISH_STOP_WORDS.union(['http', 'https'])
stop_words2
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
# ...

# %%
vectorizer = CountVectorizer(stop_words=stop_words2)
docs = vectorizer.fit_transform(df[df["Topic"]=="Software/Technology"].Tweet)
features = vectorizer.get_feature_names()
visualizer = FreqDistVisualizer(features=features,orient='h',size=(720,720))
visualizer.fit(docs)
visualizer.poof()

# %%
vectorizer = CountVectorizer(stop_words=stop_words2)
docs = vectorizer.fit_transform(df[df["Topic"]=="Banking Product"].Tweet)
features = vectorizer.get_feature_names()
visualizer = FreqDistVisualizer(features=features,orient='h',size=(0, 720),n=10)
visualizer.fit(docs)
visualizer.poof()

# %%
vectorizer = CountVectorizer(stop_words=stop_words2)
docs = vectorizer.fit_transform(df[df["Topic"]=="Economy Related"].Tweet)
features = vectorizer.get_feature_names()
visualizer = FreqDistVisualizer(features=features,orient='h',size=(720, 720))
visualizer.fit(docs)
visualizer.poof()

# %%
vectorizer = CountVectorizer(stop_words=stop_words2)
docs = vectorizer.fit_transform(df[df["Topic"]=="Mental Stress"].Tweet)
features = vectorizer.get_feature_names()
visualizer = FreqDistVisualizer(features=features,orient='h',size=(720, 720))
visualizer.fit(docs)
visualizer.poof()

# %%
vectorizer = CountVectorizer(stop_words=stop_words2)
docs = vectorizer.fit_transform(df[df["Topic"]=="Payment Related"].Tweet)
features = vectorizer.get_feature_names()
visualizer = FreqDistVisualizer(features=features,orient='h',size=(720, 720))
visualizer.fit(docs)
visualizer.poof()

# %%
from yellowbrick.text import DispersionPlot, dispersion

# Create a list of words from the corpus text
text = [doc.split() for doc in df.Tweet]

# Choose words whose occurence in the text will be plotted
target_words = ['finance', 'unemployment', 'deaths', 'business', 'impact', 'funding']

# Create the visualizer and draw the plot
dispersion(target_words, text)
# Out:
# C:\Users\Lekha\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\Lekha\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   # Remove the CWD from sys.path while we load stuff.
# DispersionPlot(annotate_docs=False,
#                ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001AD1667A080>,
#                colormap=None, colors=None, ignore_case=False, labels=None,
# ...

# %%
df['keywords'].head()
# Out:
# 0    breaking new million american filed unemployme...
# 1    determination key dictum armed force pakistan ...
# 2    happening today hope join morning join convers...
# 3    time uncertainty little clarity event unfold f...
# 4    porrohman childofalba jackson carlaw scotgov c...
# Name: keywords, dtype: object
